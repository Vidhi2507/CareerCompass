# %%
# !pip install pymongo

# %%
from pymongo.mongo_client import MongoClient

db_password = "R4u1qMX6tcmMcLFd" #will set in env file later...+whole uri
uri = f"mongodb+srv://Vidhi:{db_password}@productioncluster.cdeuc2w.mongodb.net/?appName=ProductionCluster"
client = MongoClient(uri)
db = client["CareerCompass_db"]
collection = db["Users"]

# %%
collection.insert_one({"name": "John Doe", "email": "vidhi@example.com"})
# Out:
# InsertOneResult(ObjectId('69d025a4dd5099763bff3de9'), acknowledged=True)

# %%
dbuser = collection.find_one({"email": "vidhi@example.com"})
# Out:
# {'_id': ObjectId('69d025a4dd5099763bff3de9'),
#  'name': 'John Doe',
#  'email': 'vidhi@example.com'}

# %%
from helperfunctions import create_access_token
create_access_token({"sub": "vidhi"})
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 from helperfunctions import create_access_token
#       2 create_access_token({"sub": "vidhi"})
#
# File d:\Vidhi\mca\CareerCompass\backend\helperfunctions.py:2
#       1 from datetime import datetime, timedelta
# ----> 2 import jwt
#       4 SECRET_KEY = "721"
#       5 ALGORITHM = "HS256"
#
# ModuleNotFoundError: No module named 'jwt'
